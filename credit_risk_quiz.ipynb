# %% [markdown]
# # Credit Risk — Practice Quiz
# **Instructions:** Answer each question in the cell below it. Keep answers concise — 2 to 5 sentences is usually enough.
#
# ---

# %% [markdown]
# ---
#
# ## Part 1 — Concepts & Business Context

# %% [markdown]
# ### Q1
#
# What is the difference between **PD**, **LGD**, and **EAD**? Write the formula for Expected Loss using all three.

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q2
#
# Why is **accuracy** a bad evaluation metric for a credit default model? What metric would you use instead and why?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q3
#
# What is **data leakage** in the context of a default prediction model? Give two concrete examples of leakage variables from a loan dataset.

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q4
#
# Why do we use a **stratified train/test split** instead of a random split when the default rate is 17%?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q5
#
# What does a **DSCR below 1.0** mean? Why is it a red flag for a lender?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ---
#
# ## Part 2 — EDA & Statistics

# %% [markdown]
# ### Q6
#
# If the overall default rate is 17% but one sector has a 28% default rate — does that automatically mean the sector is riskier? What confounding variable should you control for first?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q7
#
# A company has a **high current ratio but a very low cash ratio**. What does this tell you? What is this situation called?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q8
#
# What is the **Herfindahl-Hirschman Index (HHI)**? If the HHI of your loan portfolio by sector is 0.30, is that well-diversified or concentrated?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q9
#
# Explain the difference between **interest coverage ratio** and **DSCR**. Which is more conservative and why?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q10
#
# Why can **ROE be misleading** for highly leveraged companies? Give a numerical example.

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ---
#
# ## Part 3 — Feature Engineering

# %% [markdown]
# ### Q11
#
# Write out the **Altman Z-Score formula** and describe what each of the five components measures.

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q12
#
# What is **Weight of Evidence (WoE)** and **Information Value (IV)**? What IV threshold would you use to drop a feature as useless?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q13
#
# You have  in your dataset. Can you calculate  from it without any other columns? Show the formula.

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q14
#
# Why would you clip or winsorise extreme ratio values (e.g., interest coverage of 500x) before using them as model features?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ---
#
# ## Part 4 — Modelling

# %% [markdown]
# ### Q15
#
# How does **Logistic Regression** differ from a **Decision Tree** in how it draws the decision boundary? When would you prefer one over the other in a credit risk context?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q16
#
# What is **VIF (Variance Inflation Factor)**? If two features have VIF > 10, what is the problem and how do you fix it?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q17
#
# Explain **SHAP values** in plain English. Why are they useful for a credit model specifically (think: regulation)?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q18
#
# A Random Forest gets AUC-ROC = 0.82 and XGBoost gets 0.816. A bank regulator asks you to choose one for CECL provisioning. Which do you choose and why? (Hint: it may not be the higher AUC.)

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q19
#
# What does **scale_pos_weight** do in XGBoost? When and why would you set it to (number of negatives / number of positives)?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ---
#
# ## Part 5 — Portfolio Risk & Regulation

# %% [markdown]
# ### Q20
#
# What is **Basel III RWA**? How does a loan's PD affect the amount of capital a bank must hold against it?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q21
#
# Explain the three **IFRS 9 stages**. What triggers a loan to move from Stage 1 to Stage 2?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q22
#
# What is **stress testing** in a credit portfolio context? Name two macro variables you would shock and explain the direction of the effect on default rates.

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q23
#
# A portfolio has total exposure of .7 trillion and total Expected Loss of .06 trillion (22.7% EL ratio). Is this a healthy portfolio? What would a typical bank consider an acceptable EL ratio?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ### Q24
#
# What is the **Merton Distance-to-Default** model? What analogy does it use to model equity, and what does a higher DD value mean?

# %% [markdown]
# *Your answer here...*
